# %%
import pandas as pd
food_df = pd.read_csv('Food_Inspections.csv')
sidewalk = pd.read_csv('Sidewalk_Cafe_Permits_-_Current.csv')

# %%
food_df.head()
# Out:
#    Inspection ID             DBA Name            AKA Name  License #  \
# 0        2484567              ROYALTY             ROYALTY  1306130.0
# 1        2473041  ROSATI'S GRANT PARK            ROSATI'S  2762683.0
# 2        2472978        ENZO & EMILIA       ENZO & EMILIA  2762588.0
# 3        2472609      MILLENNIAL MART     MILLENNIAL MART  2528794.0
# 4        2464109   JERSEY MIKE'S SUBS  JERSEY MIKE'S SUBS  2766632.0
#
#    Facility Type           Risk                      Address     City State  \
# 0     Restaurant  Risk 1 (High)              3810 W 63RD ST   CHICAGO    IL
# 1     Restaurant  Risk 1 (High)               23 E ADAMS ST   CHICAGO    IL
# 2     Restaurant  Risk 1 (High)  2840-2542 N MILKWAUKEE AVE   CHICAGO    IL
# 3  Grocery Store   Risk 3 (Low)            848 N ORLEANS ST   CHICAGO    IL
# 4     Restaurant  Risk 1 (High)         4054 W PETERSON AVE   CHICAGO    IL
#
#        Zip Inspection Date Inspection Type    Results Violations   Latitude  \
# ...

# %%
sidewalk
# Out:
#       PERMIT NUMBER  ACCOUNT NUMBER  SITE NUMBER  \
# 0           1144484          379784            1
# 1           1144848          395072            1
# 2           1145734          372276            6
# 3           1145768           46344            2
# 4           1146032          215163            2
# ...             ...             ...          ...
# 1123        1148440          380136            1
# 1124        1148442          366847            1
# 1125        1148446          376612            1
# 1126        1148450          345226            2
# 1127        1148451          422130            2
#
#                             LEGAL NAME          DOING BUSINESS AS NAME  \
# 0                  ASIAN OUTPOST CORP.  ASIAN OUTPOST HAWAIIAN HIDEOUT
# 1             THE AVONDALE COFFEE, LLC                    AVONDALE TAP
# 2           FANNIE SCHMOE'S BAKERY LLC                   Fannie's Cafe
# 3     MICHAEL'S NEIGHBORHOOD PUB, INC.                FIREWATER SALOON
# ...

# %%
sidewalk = sidewalk.rename(columns={"LOCATION": "Location"})

# %%
Join = sidewalk.merge(food_df,on="Location", how='inner', sort=False)

# %%
Join.head()
# Out:
#    PERMIT NUMBER  ACCOUNT NUMBER  SITE NUMBER              LEGAL NAME  \
# 0        1145878          431422            1  PLEASANT PIZZA, L.L.C.
# 1        1145878          431422            1  PLEASANT PIZZA, L.L.C.
# 2        1145878          431422            1  PLEASANT PIZZA, L.L.C.
# 3        1145878          431422            1  PLEASANT PIZZA, L.L.C.
# 4        1145878          431422            1  PLEASANT PIZZA, L.L.C.
#
#   DOING BUSINESS AS NAME ISSUED DATE EXPIRATION DATE PAYMENT DATE  \
# 0            BOB'S PIZZA  07/01/2020      05/31/2021   07/01/2020
# 1            BOB'S PIZZA  07/01/2020      05/31/2021   07/01/2020
# 2            BOB'S PIZZA  07/01/2020      05/31/2021   07/01/2020
# 3            BOB'S PIZZA  07/01/2020      05/31/2021   07/01/2020
# 4            BOB'S PIZZA  07/01/2020      05/31/2021   07/01/2020
#
#        ADDRESS  ADDRESS NUMBER START  ...                      Address  \
# 0  1659 W 21ST                  1659  ...  2840-2542 N MILKWAUKEE AVE
# ...

# %%
Join.columns
# Out:
# Index(['PERMIT NUMBER', 'ACCOUNT NUMBER', 'SITE NUMBER', 'LEGAL NAME',
#        'DOING BUSINESS AS NAME', 'ISSUED DATE', 'EXPIRATION DATE',
#        'PAYMENT DATE', 'ADDRESS', 'ADDRESS NUMBER START', 'ADDRESS NUMBER',
#        'STREET DIRECTION', 'STREET', 'STREET TYPE', 'CITY', 'STATE',
#        'ZIP CODE', 'WARD', 'PRECINCT', 'WARD PRECINCT', 'POLICE DISTRICT',
#        'LATITUDE', 'LONGITUDE', 'Location', 'Inspection ID', 'DBA Name',
#        'AKA Name', 'License #', 'Facility Type', 'Risk', 'Address', 'City',
#        'State', 'Zip', 'Inspection Date', 'Inspection Type', 'Results',
#        'Violations', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
Join = Join[['Inspection ID','DBA Name','DOING BUSINESS AS NAME','AKA Name', 'License #', 'Facility Type',
       'Risk', 'Address','ADDRESS', 'Zip','ZIP CODE','Violations','PERMIT NUMBER', 'ISSUED DATE','Location']]

# %%
Join.head()
# Out:
#    Inspection ID               DBA Name DOING BUSINESS AS NAME  \
# 0        2472978          ENZO & EMILIA            BOB'S PIZZA
# 1        2352760  PLAZA FOOD AND LIQUOR            BOB'S PIZZA
# 2        2312360       PACINO'S RC, LLC            BOB'S PIZZA
# 3        2311667       PACINO'S RC, LLC            BOB'S PIZZA
# 4        2293744                NOURISH            BOB'S PIZZA
#
#                 AKA Name  License #                     Facility Type  \
# 0          ENZO & EMILIA  2762588.0                        Restaurant
# 1  PLAZA FOOD AND LIQUOR  2689757.0                     Grocery Store
# 2                PACINOS  2683669.0                        Restaurant
# 3                PACINOS  2683669.0                        Restaurant
# 4                NOURISH  2653129.0  Shared Kitchen User (Short Term)
#
#               Risk                      Address      ADDRESS      Zip  \
# 0    Risk 1 (High)  2840-2542 N MILKWAUKEE AVE   1659 W 21ST  60647.0
# ...
